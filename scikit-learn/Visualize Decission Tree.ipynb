# %%
#import lib

import matplotlib.pyplot as plt
import pandas as pd

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

from sklearn import tree

# %%
#load dataset 

data = load_iris()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
#split data 

x_train, x_test, y_train, y_test = train_test_split(df[data.feature_names], df['target'], random_state=0)

# %%
#scikit_learn 4 step modeling

#data imported already

clf = DecisionTreeClassifier(max_depth =2, random_state =0)

# %%
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=0)

# %%
clf.predict(x_test.iloc[0].values.reshape(1,-1))
# Out:
# array([2])

# %%
clf.predict(x_test[0:10])
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1, 1, 1])

# %%
#measure Performance

scr = clf.score(x_test, y_test)
print(scr)
# Out:
# 0.8947368421052632

# %%
#visulize the decission Tree

tree.plot_tree(clf)
# Out:
# [Text(133.92000000000002, 181.2, 'X[3] <= 0.8\ngini = 0.665\nsamples = 112\nvalue = [37, 34, 41]'),
#  Text(66.96000000000001, 108.72, 'gini = 0.0\nsamples = 37\nvalue = [37, 0, 0]'),
#  Text(200.88000000000002, 108.72, 'X[2] <= 4.95\ngini = 0.496\nsamples = 75\nvalue = [0, 34, 41]'),
#  Text(133.92000000000002, 36.23999999999998, 'gini = 0.153\nsamples = 36\nvalue = [0, 33, 3]'),
#  Text(267.84000000000003, 36.23999999999998, 'gini = 0.05\nsamples = 39\nvalue = [0, 1, 38]')]

# %%
fig, axes = plt.subplots(nrows =1 , ncols = 1, figsize=(4,4), dpi=300)
tree.plot_tree(clf)
# Out:
# [Text(372.0, 755.0, 'X[3] <= 0.8\ngini = 0.665\nsamples = 112\nvalue = [37, 34, 41]'),
#  Text(186.0, 453.0, 'gini = 0.0\nsamples = 37\nvalue = [37, 0, 0]'),
#  Text(558.0, 453.0, 'X[2] <= 4.95\ngini = 0.496\nsamples = 75\nvalue = [0, 34, 41]'),
#  Text(372.0, 151.0, 'gini = 0.153\nsamples = 36\nvalue = [0, 33, 3]'),
#  Text(744.0, 151.0, 'gini = 0.05\nsamples = 39\nvalue = [0, 1, 38]')]

# %%
fn = ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
cn = ['setosa', 'versicolor', 'virginica' ]

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 1, figsize= (4,4), dpi = 300)
tree.plot_tree(clf, 
              feature_names = fn,
              class_names = cn, 
              filled =True)
fig.savefig('images/plottreefncn.png')
