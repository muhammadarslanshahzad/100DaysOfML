# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil = Image.open("thor.jpg")

# %%
arr = np.array(pil)

# %%
pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=658x701 at 0x29AA381D190>

# %%
arr.shape #image above represented in pixels
# Out:
# (701, 658, 3)

# %%
cut = arr[:500, :400]

# %%
plt.imshow(cut)
