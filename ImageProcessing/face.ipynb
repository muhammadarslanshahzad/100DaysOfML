# %%
# !pip3 install opencv-python

# %%
import cv2 
import matplotlib.pyplot as plt
import numpy as np 

from PIL import Image

# %%
cv2.__version__
# Out:
# '4.5.4-dev'

# %%
frame = cv2.imread("thor.jpg")

# %%
plt.imshow(frame)

# %%
rgb__Version = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(rgb__Version)

# %%
classifier = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

# %%
faces = classifier.detectMultiScale(frame)

# %%
face = faces[0]

#face contains 4 values i.e x is the left corner y is other width && height 
x, y, w, h = face
face = rgb[y:y+h, x:x+w ]
plt.imshow(face)

# %%
face = faces[1]

#face contains 4 values i.e x is the left corner y is other width && height 
x, y, w, h = face
face = rgb[y:y+h, x:x+w ]
plt.imshow(face)

# %%
output = cv2.rectangle(rgb, (x,y), (x+w, y+h), (0, 0, 255), 4)

# %%
plt.imshow(output)
